# %%
# Import file modul
import keuangan_kos

# Input pengeluaran bulanan anak kos
uang_kos = 0
makan = 1000000
bensin = 160000
kuota = 100000
laundry = 70000
lainnya = 50000

# Hitung total pengeluaran
total = keuangan_kos.total_pengeluaran(uang_kos, makan, bensin, kuota, laundry, lainnya)
print(f"Total pengeluaran bulan ini: Rp{total}")

# Cek apakah melebihi budget
budget = 1500000
hasil = keuangan_kos.cek_budget(total, budget)
print(hasil)
# Out:
# Total pengeluaran bulan ini: Rp1380000
# Pengeluaran kamu masih aman, bagus!
