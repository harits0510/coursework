# %%
import Calculate
tambah = Calculate.tambah(10, 5)
print(f"Hasil tambah = {tambah}")
# Out:
# Hasil tambah = 15

# %%
kurang = Calculate.kurang(10, 5)
print(f"Hasil kurang = {kurang}")
# Out:
# Hasil kurang = 5

# %%
kali = Calculate.kali(10, 5)
print(f"Hasil kali = {kali}")
# Out:
# Hasil kali = 50

# %%
bagi = Calculate.bagi(10, 5)
print(f"Hasil bagi = {bagi}")
# Out:
# Hasil bagi = 2.0
