# %%
nama = input("Masukkan Nama: ")
jumlah_a = nama.lower().count('a')
print(f"Jumlah huruf 'a' dalam nama Anda adalah: {jumlah_a}")
# Out:
# Masukkan Nama:  Muhammad Harits Arrozzaq
# Jumlah huruf 'a' dalam nama Anda adalah: 5

# %%
text = "harits, yunus, fauzi"
result = " dan ".join(text.split(", "))
print(result)
# Out:
# harits dan yunus dan fauzi

# %%
text = "Saya adalah warga indonesia"
result = text.replace('a', 'i').replace('A', 'I')
print(result)
# Out:
# Siyi idilih wirgi indonesii
