# %%
username_terdaftar = "user123"
password_terdaftar = "pass123"

while True:
    username_input = input("Masukkan username: ")
    password_input = input("Masukkan password: ")
    if username_input == username_terdaftar and password_input == password_terdaftar:
        print("Login berhasil!")
        break
    else:
        print("Username atau password salah. Coba lagi.")
# Out:
# Masukkan username:  alienz
# Masukkan password:  alienz123
# Username atau password salah. Coba lagi.
# Masukkan username:  alienz123
# Masukkan password:  alienz
# Username atau password salah. Coba lagi.
# Masukkan username:  user123
# Masukkan password:  pass123
# Login berhasil!

# %%
angka = int(input("Masukkan sebuah angka: "))
pembagi = 2
is_prima = True

while pembagi < angka:
    if angka % pembagi == 0:
        is_prima = False
        break
    pembagi += 1

if is_prima:
    print(angka, "adalah bilangan prima")
else:
    print(angka, "bukan bilangan prima")
# Out:
# Masukkan sebuah angka:  87
# 87 bukan bilangan prima
